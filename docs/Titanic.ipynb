# %%
import pandas as pd

# %%
dataset = pd.read_csv('titanic_train.csv')

# %%
dataset.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
y = dataset['Survived']

# %%
X = dataset[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Cabin', 'Embarked']]

# %%
X.head(2)
# Out:
#    Pclass     Sex   Age  SibSp  Parch Cabin Embarked
# 0       3    male  22.0      1      0   NaN        S
# 1       1  female  38.0      1      0   C85        C

# %%
y.head(2)
# Out:
# 0    0
# 1    1
# Name: Survived, dtype: int64

# %%
import seaborn as sns

# %%
a = dataset.isnull()
sns.heatmap(a) #plots a graph

# %%
X = dataset[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Embarked']]
#Cabin has removed from dataset because maximum values in it was null which is not at all useful.

# %%
sns.countplot('Survived', data=dataset) #data = dataset means, we are giving argument and telling that survived column is in dataset
#It is used for counting 0s and 1s in Survived column

# %%
sns.countplot('Survived', data=dataset, hue='Sex')

# %%
#The above result tells us that maximum male died and females survived
#hue means that this plot should be made with corresponding to sex column.sns.countplot('Survived', data=dataset)
#This is one of the way of feature engineering.sns.countplot('Survived', data=dataset)

# %%
sns.countplot('Survived', data=dataset, hue='Pclass')

# %%
#3rd class people's survival rate is very less.

# %%
sns.heatmap(X.isnull())

# %%
sns.countplot('Survived', data=dataset, hue='Age')

# %%
#X.dropna(inplace=True)
#gender = X['Sex']
#gender_dummy = pd.get_dummies(gender,drop_first=True)
